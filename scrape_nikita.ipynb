# %%
from Scweet.scweet import scrape

# %%
niki = scrape(since='2014-03-01', save_dir='nikita', 
              from_account='nktgill', display_type='image', save_images=True, interval=10,)
# Out:
# Scraping on headless mode.
# looking for tweets between 2014-03-01 and 2014-03-11 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2014-03-11%20since%3A2014-03-01%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2014-03-11 and 2014-03-21 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2014-03-21%20since%3A2014-03-11%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2014-03-21 and 2014-03-31 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2014-03-31%20since%3A2014-03-21%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2014-03-31 and 2014-04-10 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2014-04-10%20since%3A2014-03-31%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2014-04-10 and 2014-04-20 ...
# ...

# %%
niki
# Out:
# Empty DataFrame
# Columns: [UserScreenName, UserName, Timestamp, Text, Embedded_text, Emojis, Comments, Likes, Retweets, Image link, Tweet URL]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('nikita/nktgill_2014-03-01_2022-12-14.csv')

# %%
df
# Out:
# Empty DataFrame
# Columns: [UserScreenName, UserName, Timestamp, Text, Embedded_text, Emojis, Comments, Likes, Retweets, Image link, Tweet URL]
# Index: []

# %%
nikita = scrape(since='2022-09-04', save_dir='nikita2', 
              from_account='nktgill', display_type='image', save_images=True, interval=1)
# Out:
# Scraping on headless mode.
# looking for tweets between 2022-09-04 and 2022-09-05 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2022-09-05%20since%3A2022-09-04%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2022-09-05 and 2022-09-06 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2022-09-06%20since%3A2022-09-05%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2022-09-06 and 2022-09-07 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2022-09-07%20since%3A2022-09-06%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2022-09-07 and 2022-09-08 ...
#  path : https://twitter.com/search?q=(from%3Anktgill)%20until%3A2022-09-08%20since%3A2022-09-07%20&src=typed_query&f=image
# scroll  1
# scroll  2
# looking for tweets between 2022-09-08 and 2022-09-09 ...
# ...

# %%
nikita
# Out:
# Empty DataFrame
# Columns: [UserScreenName, UserName, Timestamp, Text, Embedded_text, Emojis, Comments, Likes, Retweets, Image link, Tweet URL]
# Index: []

# %%
nikita = scrape(since='2022-12-10', save_dir='test', headless=False,
              from_account='MayaCPopa', display_type='image', save_images=True, interval=1)

# %%
ordernumber = 2605
